# %% [markdown]
# # HEADINGS

# %%
# This code is prepared by Orhan Erdem

# %%
# BIG HEADING
## SMALL HEADING
### SMALLER HEADING
#### SMALLEST HEADING

# %% [markdown]
# These codes are prepared to be used in Jupyter. However, you should be good to run these in Google Colab too.
# In this section, we will review how to annotate and incorporate comments between code snippets. First, let’s start with headings. To craft a heading, select the “Markdown” option from the toolbar, enter the desired heading into the blank cell. The format is a number sign (#) followed by a space and then the text. For example, you can insert the following text into your cell. You can run the following code:

# %%
This is a normal text

*This text will be in italic.*

**This text will be bold.**

# %%
print('Hello') #Here I am greeting the readers.

# %%
"""
This is an explanation
"""

# %% [markdown]
# # ARITHMETIC OPERATIONS

# %%
3+2

# %%
3-2

# %%
6/3

# %%
3*2

# %%
7//3

# %%
2**3

# %%
15==16

# %%
15>10

# %%
15!=14

# %%
"How about 15=15"

# %%
print(float(10))

# %%
x=10 #assigns value

# %%
y=5

# %% [markdown]
# # DATA TYPES

# %%
#String, Float, Integer, Boolean

# %%
a='My variable'

# %%
type(a)

# %%
len(a)

# %%
b='The University'
b=b.lower()

# %%
c=' of North Texas'
c=c.upper()

# %%
b+c

# %%
type(b)

# %%
type(c)

# %%
d=5/2
d

# %%
type(d)

# %%
e=5

# %%
type(e)

# %%
print(5 / 2)

# %%
print(int('807') + 1)

# %% [markdown]
# ## Quick Quiz

# %%
x='5'
y='10'
x+y

# %% [markdown]
# # Example

# %%
Height=6

# %%
print('Height')

# %%
print(Height)

# %%
print('Height is', Height)

# %%
# This code is prepared by Orhan Erdem
