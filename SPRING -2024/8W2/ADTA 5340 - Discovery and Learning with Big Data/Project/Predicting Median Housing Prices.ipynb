# %%
#import 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
Residential_data = pd.read_csv('RDC_Inventory_Core_Metrics_County_History.csv')

# %%
Residential_data.head()
# Out:
#    month_date_yyyymm  county_fips  county_name  median_listing_price  \
# 0             202403        48205  hartley, tx              425000.0
# 1             202403        27133     rock, mn              309900.0
# 2             202403        40019   carter, ok              199000.0
# 3             202403        42083   mckean, pa              169000.0
# 4             202403         1055   etowah, al              248950.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   0.1824                   0.6915                  12.0
# 1                   0.0376                   0.2689                  21.0
# 2                  -0.0499                  -0.0328                 165.0
# 3                  -0.0663                   0.3000                  48.0
# 4                  -0.0130                   0.1609                 236.0
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...
