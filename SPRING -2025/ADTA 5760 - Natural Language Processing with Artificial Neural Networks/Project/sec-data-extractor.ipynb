# %%
import requests
import pandas as pd
from typing import List, Dict, Any
import time
import json

class SECDataExtractor:
    def __init__(self, api_key: str):
        self.api_key = api_key

    def get_filings(self, limit: int = 200) -> List[Dict[str, Any]]:
        """
        Fetch SEC filings using the EDGAR API endpoint.
        
        Args:
            limit (int): Number of filings to retrieve (default: 100)
            
        Returns:
            List[Dict]: List of filing data
        """
        try:
            # Construct the query according to documentation
            payload = {
                "query": "formType:\"10-K\" OR formType:\"10-Q\"",
                "from": 0,
                "size": limit,
                "sort": [{"filedAt": {"order": "desc"}}]
            }

            # Make request to the EDGAR endpoint
            url = "https://api.sec-api.io/?token=" + self.api_key
            headers = {
                'Content-Type': 'application/json'
            }

            print(f"Making request to: {url}")
            print(f"With payload: {json.dumps(payload, indent=2)}")
            
            response = requests.post(url, headers=headers, json=payload)

            if response.status_code == 429:
                retry_after = int(response.headers.get('Retry-After', 60))
                print(f"Rate limit hit. Waiting {retry_after} seconds...")
                time.sleep(retry_after)
                return self.get_filings(limit)

            response.raise_for_status()
            
            data = response.json()
            
            # Process the filings
            processed_filings = []
            for filing in data.get('filings', []):
                processed_filings.append({
                    'accessionNo': filing.get('accessionNo', ''),
                    'cik': filing.get('cik', ''),
                    'ticker': filing.get('ticker', ''),
                    'companyName': filing.get('companyName', ''),
                    'formType': filing.get('formType', ''),
                    'filedAt': filing.get('filedAt', ''),
                    'filing_url': filing.get('linkToFilingDetails', '')
                })
            
            return processed_filings

        except requests.exceptions.RequestException as e:
            print(f"Error fetching SEC filings: {e}")
            if hasattr(e, 'response'):
                print(f"Status code: {e.response.status_code}")
                if hasattr(e.response, 'text'):
                    print(f"Response text: {e.response.text}")
            return []

    def save_to_csv(self, filings: List[Dict[str, Any]], filename: str = 'sec_filings.csv'):
        """
        Save the filing data to a CSV file.
        
        Args:
            filings (List[Dict]): List of filing data
            filename (str): Output filename
        """
        if not filings:
            print("No data to save")
            return
            
        df = pd.DataFrame(filings)
        df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")

def main():
    # Your API key
    API_KEY = "b3eacaa72e15fec1ef69bbd2a71dcbb790fdf6ab38c852436df88f306b98d2d0"
    
    # Initialize the extractor
    extractor = SECDataExtractor(API_KEY)
    
    # Get the filings
    print("Fetching SEC filings...")
    filings = extractor.get_filings(limit=200)
    
    if filings:
        print(f"\nRetrieved {len(filings)} filings")
        
        # Display first few entries
        print("\nSample of retrieved data:")
        for filing in filings[:5]:
            print(f"\nAccession No: {filing['accessionNo']}")
            print(f"CIK: {filing['cik']}")
            print(f"Ticker: {filing['ticker']}")
            print(f"Company: {filing['companyName']}")
            print(f"Form Type: {filing['formType']}")
            print(f"Filed At: {filing['filedAt']}")
            print(f"Filing URL: {filing['filing_url']}")
        
        # Save to CSV
        extractor.save_to_csv(filings)
    else:
        print("\nNo filings retrieved. Make sure:")
        print("1. Your API key is valid")
        print("2. You have an active subscription")
        print("3. You're not exceeding rate limits")

if __name__ == "__main__":
    main()
# Out:
# Fetching SEC filings...
# Making request to: https://api.sec-api.io/?token=b3eacaa72e15fec1ef69bbd2a71dcbb790fdf6ab38c852436df88f306b98d2d0
# With payload: {
#   "query": "formType:\"10-K\" OR formType:\"10-Q\"",
#   "from": 0,
#   "size": 200,
#   "sort": [
#     {
#       "filedAt": {
#         "order": "desc"
#       }
#     }
#   ]
# }
#
# Retrieved 200 filings
#
# Sample of retrieved data:
#
# Accession No: 0001628280-25-005486
# CIK: 1702780
# Ticker: ATUS
# Company: Altice USA, Inc.
# Form Type: 10-K
# Filed At: 2025-02-13T17:29:28-05:00
# Filing URL: https://www.sec.gov/Archives/edgar/data/1702780/000162828025005486/atus-20241231.htm
#
# Accession No: 0000927066-25-000012
# CIK: 927066
# Ticker: DVA
# Company: DAVITA INC.
# Form Type: 10-K
# Filed At: 2025-02-13T17:25:47-05:00
# Filing URL: https://www.sec.gov/Archives/edgar/data/927066/000092706625000012/dva-20241231.htm
#
# Accession No: 0001411685-25-000019
# CIK: 1411685
# Ticker: VTGN
# Company: Vistagen Therapeutics, Inc.
# Form Type: 10-Q
# Filed At: 2025-02-13T17:25:15-05:00
# Filing URL: https://www.sec.gov/Archives/edgar/data/1411685/000141168525000019/vtgn-20241231.htm
#
# Accession No: 0001493152-25-006484
# CIK: 704172
# Ticker: PHIL
# Company: PHI GROUP INC
# Form Type: NT 10-Q
# Filed At: 2025-02-13T17:24:20-05:00
# Filing URL: https://www.sec.gov/Archives/edgar/data/704172/000149315225006484/formnt10-q.htm
#
# Accession No: 0001506307-25-000008
# CIK: 1506307
# Ticker: KMI
# Company: KINDER MORGAN, INC.
# Form Type: 10-K
# Filed At: 2025-02-13T17:22:04-05:00
# Filing URL: https://www.sec.gov/Archives/edgar/data/1506307/000150630725000008/kmi-20241231.htm
# Data saved to sec_filings.csv

# %%
import pandas as pd
import requests
import os
from typing import Optional
import time
from urllib.parse import quote

class SECPDFDownloader:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "https://api.sec-api.io/filing-reader"
        self.failed_downloads = []

    def download_pdf(self, filing_url: str, output_dir: str, filename: Optional[str] = None) -> bool:
        """
        Download a filing as PDF using the SEC API.
        
        Args:
            filing_url (str): URL of the filing
            output_dir (str): Directory to save the PDF
            filename (str, optional): Custom filename for the PDF
            
        Returns:
            bool: True if download successful, False otherwise
        """
        try:
            # Construct the API URL
            params = {
                'token': self.api_key,
                'url': filing_url
            }
            
            print(f"Downloading: {filing_url}")
            response = requests.get(self.base_url, params=params)
            
            if response.status_code == 429:  # Rate limit
                retry_after = int(response.headers.get('Retry-After', 60))
                print(f"Rate limit hit. Waiting {retry_after} seconds...")
                time.sleep(retry_after)
                return self.download_pdf(filing_url, output_dir, filename)
            
            response.raise_for_status()
            
            # Generate filename if not provided
            if not filename:
                parts = filing_url.split('/')
                filename = f"filing_{parts[-1].replace('.htm', '')}.pdf"
            
            # Ensure .pdf extension
            if not filename.endswith('.pdf'):
                filename += '.pdf'
            
            # Create output directory if it doesn't exist
            os.makedirs(output_dir, exist_ok=True)
            
            # Save the PDF
            output_path = os.path.join(output_dir, filename)
            with open(output_path, 'wb') as f:
                f.write(response.content)
            
            print(f"Successfully downloaded: {output_path}")
            return True
            
        except requests.exceptions.RequestException as e:
            print(f"Error downloading {filing_url}: {e}")
            if hasattr(e, 'response') and hasattr(e.response, 'text'):
                print(f"Response text: {e.response.text}")
            self.failed_downloads.append((filing_url, str(e)))
            return False
        except Exception as e:
            print(f"Unexpected error downloading {filing_url}: {e}")
            self.failed_downloads.append((filing_url, str(e)))
            return False

def main():
    # Your API key
    API_KEY = "b3eacaa72e15fec1ef69bbd2a71dcbb790fdf6ab38c852436df88f306b98d2d0"
    
    # Create downloader instance
    downloader = SECPDFDownloader(API_KEY)
    
    # Output directory for PDFs
    output_dir = "sec_filings_pdf"
    
    try:
        # Read the CSV file
        df = pd.read_csv('sec_filings.csv')
        
        print(f"Found {len(df)} filings in CSV file")
        
        # Create counters
        successful = 0
        failed = 0
        
        # Download each filing
        for index, row in df.iterrows():
            try:
                filing_url = row['filing_url']
                if pd.isna(filing_url) or not filing_url:
                    print(f"Skipping row {index}: No filing URL")
                    continue
                
                # Create filename using company name and form type
                safe_company_name = "".join(x for x in row['companyName'] if x.isalnum() or x in [' ', '-', '_'])
                filename = f"{safe_company_name}_{row['formType']}_{row['filedAt'][:10]}.pdf"
                
                # Download the PDF
                if downloader.download_pdf(filing_url, output_dir, filename):
                    successful += 1
                else:
                    failed += 1
                
                # Add a small delay to avoid rate limits
                time.sleep(1)
                
            except Exception as e:
                print(f"Error processing row {index}: {e}")
                failed += 1
                continue
        
        print(f"\nDownload summary:")
        print(f"Successfully downloaded: {successful} / {len(df)} filings")
        print(f"Failed downloads: {failed}")
        print(f"PDFs saved in: {os.path.abspath(output_dir)}")
        
        if downloader.failed_downloads:
            print("\nFailed downloads details:")
            for url, error in downloader.failed_downloads:
                print(f"URL: {url}")
                print(f"Error: {error}\n")
        
    except FileNotFoundError:
        print("Error: sec_filings.csv not found in the current directory!")
        print(f"Current directory: {os.getcwd()}")
        print("Please make sure the CSV file exists in this location.")
    except pd.errors.EmptyDataError:
        print("Error: The CSV file is empty!")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Found 200 filings in CSV file
# Downloading: https://www.sec.gov/Archives/edgar/data/1702780/000162828025005486/atus-20241231.htm
# Successfully downloaded: sec_filings_pdf\Altice USA Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/927066/000092706625000012/dva-20241231.htm
# Successfully downloaded: sec_filings_pdf\DAVITA INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1411685/000141168525000019/vtgn-20241231.htm
# Successfully downloaded: sec_filings_pdf\Vistagen Therapeutics Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/704172/000149315225006484/formnt10-q.htm
# Successfully downloaded: sec_filings_pdf\PHI GROUP INC_NT 10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1506307/000150630725000008/kmi-20241231.htm
# Successfully downloaded: sec_filings_pdf\KINDER MORGAN INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1409970/000140997025000009/lc-20241231.htm
# Successfully downloaded: sec_filings_pdf\LendingClub Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1725430/000149315225006477/form10-ka.htm
# Unexpected error downloading https://www.sec.gov/Archives/edgar/data/1725430/000149315225006477/form10-ka.htm: [Errno 2] No such file or directory: 'sec_filings_pdf\\INTELLIGENT BIO SOLUTIONS INC_10-K/A_2025-02-13.pdf'
# Downloading: https://www.sec.gov/Archives/edgar/data/1822250/000095017025020033/logc-20240930.htm
# Unexpected error downloading https://www.sec.gov/Archives/edgar/data/1822250/000095017025020033/logc-20240930.htm: [Errno 2] No such file or directory: 'sec_filings_pdf\\ContextLogic Inc_10-Q/A_2025-02-13.pdf'
# Downloading: https://www.sec.gov/Archives/edgar/data/1650132/000095017025020029/fcpt-20241231.htm
# Successfully downloaded: sec_filings_pdf\Four Corners Property Trust Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1762303/000095017025020026/rcel-20241231.htm
# Successfully downloaded: sec_filings_pdf\AVITA Medical Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1597264/000155837025000953/bpmc-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\Blueprint Medicines Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1665918/000166591825000017/usfd-20241228.htm
# Successfully downloaded: sec_filings_pdf\US Foods Holding Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1923891/000149315225006474/form10-q.htm
# Successfully downloaded: sec_filings_pdf\Nano Nuclear Energy Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1174922/000117492225000039/wynn-20241231.htm
# Successfully downloaded: sec_filings_pdf\WYNN RESORTS LTD_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/91440/000009144025000010/sna-20241228.htm
# Successfully downloaded: sec_filings_pdf\Snap-on Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/89089/000008908925000011/sci-20241231.htm
# Successfully downloaded: sec_filings_pdf\SERVICE CORP INTERNATIONAL_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1025996/000102599625000052/krc-20241231.htm
# Successfully downloaded: sec_filings_pdf\KILROY REALTY CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1025996/000102599625000052/krc-20241231.htm
# Successfully downloaded: sec_filings_pdf\Kilroy Realty LP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1043219/000162828025005451/nly-20241231.htm
# Successfully downloaded: sec_filings_pdf\ANNALY CAPITAL MANAGEMENT INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1456772/000145677225000013/opi-20241231.htm
# Successfully downloaded: sec_filings_pdf\OFFICE PROPERTIES INCOME TRUST_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/877212/000087721225000027/zbra-20241231.htm
# Successfully downloaded: sec_filings_pdf\ZEBRA TECHNOLOGIES CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/5272/000000527225000012/aig-20241231.htm
# Successfully downloaded: sec_filings_pdf\AMERICAN INTERNATIONAL GROUP INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1052752/000095017025019976/gty-20241231.htm
# Successfully downloaded: sec_filings_pdf\GETTY REALTY CORP MD_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1506929/000164033425000251/vrdr_10q.htm
# Successfully downloaded: sec_filings_pdf\VERDE RESOURCES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1627475/000162747525000011/upwk-20241231.htm
# Successfully downloaded: sec_filings_pdf\UPWORK INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1691303/000169130325000010/hcc-20241231.htm
# Successfully downloaded: sec_filings_pdf\WARRIOR MET COAL INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1755101/000109690625000156/alds-20241231.htm
# Successfully downloaded: sec_filings_pdf\APPlife Digital Solutions Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1733861/000118518525000130/restez20240331_10k.htm
# Successfully downloaded: sec_filings_pdf\REST EZ Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/740260/000074026025000052/vtr-20241231.htm
# Successfully downloaded: sec_filings_pdf\Ventas Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1477246/000095017025019956/sanw-20241231.htm
# Successfully downloaded: sec_filings_pdf\SW Seed Co_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/719413/000095017025019955/hl-20241231.htm
# Successfully downloaded: sec_filings_pdf\HECLA MINING CODE_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/749251/000074925125000008/it-20241231.htm
# Successfully downloaded: sec_filings_pdf\GARTNER INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1253689/000155837025000948/glyc-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\GLYCOMIMETICS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1631282/000121390025013537/ea0230219-10q_datasea.htm
# Successfully downloaded: sec_filings_pdf\DATASEA INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1888654/000095017025019943/feam-20241231.htm
# Successfully downloaded: sec_filings_pdf\5E Advanced Materials Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1137774/000113777425000044/pru-20241231.htm
# Successfully downloaded: sec_filings_pdf\PRUDENTIAL FINANCIAL INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/40570/000147793225000956/job_10q.htm
# Successfully downloaded: sec_filings_pdf\GEE Group Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/84839/000008483925000024/rol-20241231.htm
# Successfully downloaded: sec_filings_pdf\ROLLINS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1679788/000167978825000022/coin-20241231.htm
# Successfully downloaded: sec_filings_pdf\Coinbase Global Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1280784/000128078425000007/htgc-20241231.htm
# Successfully downloaded: sec_filings_pdf\Hercules Capital Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1136893/000113689325000014/fis-20241231.htm
# Successfully downloaded: sec_filings_pdf\Fidelity National Information Services Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1910139/000141057825000127/mbly-20241228x10k.htm
# Successfully downloaded: sec_filings_pdf\Mobileye Global Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1552033/000155203325000015/tru-20241231.htm
# Successfully downloaded: sec_filings_pdf\TransUnion_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1145255/000143774925003757/hnna20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\HENNESSY ADVISORS INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1106838/000149315225006436/form10-q.htm
# Successfully downloaded: sec_filings_pdf\Sonnet BioTherapeutics Holdings Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/867840/000168316825000995/poci_i10q-123124.htm
# Successfully downloaded: sec_filings_pdf\PRECISION OPTICS CORPORATION INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/906107/000095017025019894/eqr-20241231.htm
# Successfully downloaded: sec_filings_pdf\EQUITY RESIDENTIAL_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/906107/000095017025019894/eqr-20241231.htm
# Successfully downloaded: sec_filings_pdf\ERP OPERATING LTD PARTNERSHIP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/34903/000003490325000016/frt-20241231.htm
# Successfully downloaded: sec_filings_pdf\Federal Realty OP LP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/34903/000003490325000016/frt-20241231.htm
# Successfully downloaded: sec_filings_pdf\FEDERAL REALTY INVESTMENT TRUST_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1757073/000175707325000007/nvst-20241231.htm
# Successfully downloaded: sec_filings_pdf\Envista Holdings Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/88121/000008812125000017/seb-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\SEABOARD CORP DE_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/744452/000141057825000126/apdn-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\APPLIED DNA SCIENCES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1866581/000186658125000048/bros-20241231.htm
# Successfully downloaded: sec_filings_pdf\Dutch Bros Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/200406/000020040625000038/jnj-20241229.htm
# Successfully downloaded: sec_filings_pdf\JOHNSON  JOHNSON_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1587523/000158752325000010/kn-20241231.htm
# Successfully downloaded: sec_filings_pdf\Knowles Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1014473/000101447325000006/vrsn-20241231.htm
# Successfully downloaded: sec_filings_pdf\VERISIGN INCCA_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/38264/000168316825000993/forward_i10q-123124.htm
# Successfully downloaded: sec_filings_pdf\Forward Industries Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1368458/000095017025019869/sbh-20241231.htm
# Successfully downloaded: sec_filings_pdf\Sally Beauty Holdings Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1307748/000130774825000028/ivtp-20241231.htm
# Successfully downloaded: sec_filings_pdf\InvenTrust Properties Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1644903/000143774925003752/ycbd20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\cbdMD Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1053369/000149315225006427/form10-q.htm
# Successfully downloaded: sec_filings_pdf\ELITE PHARMACEUTICALS INC NV_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1998781/000149315225006426/form10-q.htm
# Successfully downloaded: sec_filings_pdf\IB Acquisition Corp_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/21665/000002166525000008/cl-20241231.htm
# Successfully downloaded: sec_filings_pdf\COLGATE PALMOLIVE CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1559720/000155972025000010/abnb-20241231.htm
# Successfully downloaded: sec_filings_pdf\Airbnb Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1492617/000149315225006388/form10-q.htm
# Successfully downloaded: sec_filings_pdf\FLYWHEEL ADVANCED TECHNOLOGY INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1487712/000162828025005392/al-20241231.htm
# Successfully downloaded: sec_filings_pdf\AIR LEASE CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/759944/000075994425000013/cfg-20241231.htm
# Successfully downloaded: sec_filings_pdf\CITIZENS FINANCIAL GROUP INCRI_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/793733/000155837025000943/skyw-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\SKYWEST INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1508655/000095017025019845/tslx-20241231.htm
# Successfully downloaded: sec_filings_pdf\Sixth Street Specialty Lending Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1823584/000149315225006421/form10-q.htm
# Successfully downloaded: sec_filings_pdf\ALLIANCE ENTERTAINMENT HOLDING CORP_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/875320/000087532025000053/vrtx-20241231.htm
# Successfully downloaded: sec_filings_pdf\VERTEX PHARMACEUTICALS INC  MA_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1066194/000155837025000941/egan-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\EGAIN Corp_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1468174/000146817425000009/h-20241231.htm
# Successfully downloaded: sec_filings_pdf\Hyatt Hotels Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1074871/000121390025013462/ea0230149-10q_modular.htm
# Successfully downloaded: sec_filings_pdf\Modular Medical Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1836754/000149315225006418/form10-q.htm
# Successfully downloaded: sec_filings_pdf\Legacy Education Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/26324/000002632425000015/cw-20241231.htm
# Successfully downloaded: sec_filings_pdf\CURTISS WRIGHT CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/802481/000080248125000011/ppc-20241229.htm
# Successfully downloaded: sec_filings_pdf\PILGRIMS PRIDE CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1016178/000101617825000005/carv-20241231.htm
# Successfully downloaded: sec_filings_pdf\CARVER BANCORP INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/913142/000091314225000005/bdc-20241231.htm
# Successfully downloaded: sec_filings_pdf\BELDEN INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1016504/000143774925003744/inbp20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\INTEGRATED BIOPHARMA INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1889539/000188953925000014/crbg-20241231.htm
# Successfully downloaded: sec_filings_pdf\Corebridge Financial Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/313927/000095017025019801/chd-20241231.htm
# Successfully downloaded: sec_filings_pdf\CHURCH  DWIGHT CO INC DE_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1334036/000133403625000009/crox-20241231.htm
# Successfully downloaded: sec_filings_pdf\Crocs Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/315213/000031521325000007/rhi-20241231.htm
# Successfully downloaded: sec_filings_pdf\ROBERT HALF INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/62362/000095017025019761/marps_10-q_2024-12-31_no.htm
# Successfully downloaded: sec_filings_pdf\MARINE PETROLEUM TRUST_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1913838/000155837025000936/vwfb-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\VWF Bancorp Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1722684/000172268425000005/wh-20241231.htm
# Successfully downloaded: sec_filings_pdf\WYNDHAM HOTELS  RESORTS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1555280/000155528025000102/zts-20241231.htm
# Successfully downloaded: sec_filings_pdf\Zoetis Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1930087/000193008725000012/gcred-20241231.htm
# Successfully downloaded: sec_filings_pdf\Golub Capital Private Credit Fund_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/863894/000143774925003734/veru20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\VERU INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1338749/000095017025019711/pch-20241231.htm
# Successfully downloaded: sec_filings_pdf\POTLATCHDELTIC CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55785/000005578525000013/kmb-20241231.htm
# Successfully downloaded: sec_filings_pdf\KIMBERLY CLARK CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/2027537/000202753725000004/gsreft-20241231.htm
# Successfully downloaded: sec_filings_pdf\Goldman Sachs Real Estate Finance Trust Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1337068/000117494725000166/mgyr-20241231.htm
# Successfully downloaded: sec_filings_pdf\Magyar Bancorp Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1786842/000178684225000008/vnt-20241231.htm
# Successfully downloaded: sec_filings_pdf\Vontier Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/910108/000144483825000023/lxp-20241231.htm
# Successfully downloaded: sec_filings_pdf\LXP Industrial Trust_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55135/000005513525000007/kelya-20241229.htm
# Successfully downloaded: sec_filings_pdf\KELLY SERVICES INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/28385/000093634025000065/dte-20241231.htm
# Successfully downloaded: sec_filings_pdf\DTE ENERGY CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/28385/000093634025000065/dte-20241231.htm
# Successfully downloaded: sec_filings_pdf\DTE Electric Co_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/918573/000142050625000365/form12b25dotcom_163.htm
# Successfully downloaded: sec_filings_pdf\GROOVE BOTANICALS INC_NT 10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1039280/000149315225006348/form10-q.htm
# Successfully downloaded: sec_filings_pdf\NETSOL TECHNOLOGIES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/106640/000010664025000011/whr-20241231.htm
# Successfully downloaded: sec_filings_pdf\WHIRLPOOL CORP DE_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/24741/000162828025005347/glw-20241231.htm
# Successfully downloaded: sec_filings_pdf\CORNING INC NY_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1411168/000137647425000204/dug-20241231.htm
# Successfully downloaded: sec_filings_pdf\Dutch Oven Gold Group Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1163739/000155837025000926/nbr-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\NABORS INDUSTRIES LTD_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/2020919/000168316825000984/deltasoft_i10q-123124.htm
# Successfully downloaded: sec_filings_pdf\DeltaSoft Corp_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1639327/000121390025013284/ea0230968-nt10q_zhuoxun.htm
# Successfully downloaded: sec_filings_pdf\Zhuoxun Hongtu Inc_NT 10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55387/000092222425000009/ppl-20241231.htm
# Successfully downloaded: sec_filings_pdf\KENTUCKY UTILITIES CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55387/000092222425000009/ppl-20241231.htm
# Successfully downloaded: sec_filings_pdf\PPL Corp_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55387/000092222425000009/ppl-20241231.htm
# Successfully downloaded: sec_filings_pdf\PPL ELECTRIC UTILITIES CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/55387/000092222425000009/ppl-20241231.htm
# Successfully downloaded: sec_filings_pdf\LOUISVILLE GAS  ELECTRIC CO KY_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/96885/000118518525000123/tikk-20241231.htm
# Successfully downloaded: sec_filings_pdf\TEL INSTRUMENT ELECTRONICS CORP_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1770236/000177023625000008/mitq-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\MOVING iMAGE TECHNOLOGIES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1374881/000147793225000938/king_10q.htm
# Successfully downloaded: sec_filings_pdf\Kingfish Holding Corp_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1968915/000196891525000006/phin-20241231.htm
# Successfully downloaded: sec_filings_pdf\PHINIA INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1521945/000152194525000018/pfloat-20241231.htm
# Successfully downloaded: sec_filings_pdf\Prospect Floating Rate  Alternative Income Fund Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/888491/000088849125000006/ohi-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\OMEGA HEALTHCARE INVESTORS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/732026/000143774925003692/trt20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\TRIO-TECH INTERNATIONAL_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\AEP Texas Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\APPALACHIAN POWER CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\PUBLIC SERVICE CO OF OKLAHOMA_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\OHIO POWER CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\SOUTHWESTERN ELECTRIC POWER CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\INDIANA MICHIGAN POWER CO_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\AMERICAN ELECTRIC POWER CO INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/4904/000000490425000027/aep-20241231.htm
# Successfully downloaded: sec_filings_pdf\AEP Transmission Company LLC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1300781/000168316825000979/dh_ext.htm
# Successfully downloaded: sec_filings_pdf\DH ENCHANTMENT INC_NT 10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1616862/000161686225000013/axta-20241231.htm
# Successfully downloaded: sec_filings_pdf\Axalta Coating Systems Ltd_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1439222/000143922225000009/agio-20241231.htm
# Successfully downloaded: sec_filings_pdf\AGIOS PHARMACEUTICALS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/889971/000165495425001434/lpth_10q.htm
# Successfully downloaded: sec_filings_pdf\LIGHTPATH TECHNOLOGIES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/911216/000165495425001431/ptn_10q.htm
# Successfully downloaded: sec_filings_pdf\PALATIN TECHNOLOGIES INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1411207/000095017025019379/alsn-20241231.htm
# Successfully downloaded: sec_filings_pdf\Allison Transmission Holdings Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1178670/000117867025000026/alny-20241231.htm
# Successfully downloaded: sec_filings_pdf\ALNYLAM PHARMACEUTICALS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1854445/000149315225006263/form10-q.htm
# Successfully downloaded: sec_filings_pdf\Glimpse Group Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1725430/000149315225006262/form10-q.htm
# Successfully downloaded: sec_filings_pdf\INTELLIGENT BIO SOLUTIONS INC_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/48898/000162828025005311/hubb-20241231.htm
# Successfully downloaded: sec_filings_pdf\HUBBELL INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/937098/000093709825000016/tnet-20241231.htm
# Successfully downloaded: sec_filings_pdf\TRINET GROUP INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/93751/000009375125000111/stt-20241231.htm
# Successfully downloaded: sec_filings_pdf\STATE STREET CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1026214/000102621425000040/fmcc-20241231.htm
# Successfully downloaded: sec_filings_pdf\FEDERAL HOME LOAN MORTGAGE CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1617867/000143774925003669/amix20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\Autonomix Medical Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1637459/000163745925000011/khc-20241228.htm
# Successfully downloaded: sec_filings_pdf\Kraft Heinz Co_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1478242/000147824225000045/iqv-20241231.htm
# Successfully downloaded: sec_filings_pdf\IQVIA HOLDINGS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1835385/000155837025000901/mara-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\Marathon Bancorp Inc MD_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1444192/000114036125004153/ef20039004_10q.htm
# Successfully downloaded: sec_filings_pdf\Grace Therapeutics Inc_10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1534504/000153450425000011/pbf-20241231.htm
# Successfully downloaded: sec_filings_pdf\PBF Energy Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1418819/000162828025005302/irdm-20241231.htm
# Successfully downloaded: sec_filings_pdf\Iridium Communications Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/86312/000008631225000012/trv-20241231.htm
# Successfully downloaded: sec_filings_pdf\TRAVELERS COMPANIES INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1364479/000136447925000007/hri-20241231.htm
# Successfully downloaded: sec_filings_pdf\HERC HOLDINGS INC_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/851205/000085120525000012/cgnx-20241231.htm
# Successfully downloaded: sec_filings_pdf\COGNEX CORP_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1932393/000193239325000005/gehc-20241231.htm
# Successfully downloaded: sec_filings_pdf\GE HealthCare Technologies Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1433551/000149315225006216/formnt10-q.htm
# Successfully downloaded: sec_filings_pdf\Sino Green Land Corp_NT 10-Q_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1544400/000147793225000927/nftn_10k.htm
# Successfully downloaded: sec_filings_pdf\NFiniTi inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1318220/000155837025000893/wcn-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\Waste Connections Inc_10-K_2025-02-13.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/75488/000100498025000010/pcg-20241231.htm
# Successfully downloaded: sec_filings_pdf\PACIFIC GAS  ELECTRIC Co_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/75488/000100498025000010/pcg-20241231.htm
# Successfully downloaded: sec_filings_pdf\PGE Corp_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/85535/000008553525000012/rgld-20241231.htm
# Successfully downloaded: sec_filings_pdf\ROYAL GOLD INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/66756/000006675625000013/ale-20241231.htm
# Successfully downloaded: sec_filings_pdf\ALLETE INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1993004/000199300425000021/nweg-20241231.htm
# Successfully downloaded: sec_filings_pdf\NorthWestern Energy Group Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1770787/000177078725000013/txg-20241231.htm
# Successfully downloaded: sec_filings_pdf\10x Genomics Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1958086/000095017025019072/clb-20241231.htm
# Successfully downloaded: sec_filings_pdf\Core Laboratories Inc DE_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1713445/000171344525000018/rddt-20241231.htm
# Successfully downloaded: sec_filings_pdf\Reddit Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/79282/000095017025019039/bro-20241231.htm
# Successfully downloaded: sec_filings_pdf\BROWN  BROWN INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1728328/000121390025013063/ea0228900-10q_inmed.htm
# Successfully downloaded: sec_filings_pdf\InMed Pharmaceuticals Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/875045/000087504525000009/biib-20241231.htm
# Successfully downloaded: sec_filings_pdf\BIOGEN INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1393584/000095017025019024/amwl-20241231.htm
# Successfully downloaded: sec_filings_pdf\American Well Corp_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1743907/000174390725000005/sncy-20241231.htm
# Successfully downloaded: sec_filings_pdf\Sun Country Airlines Holdings Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/732717/000073271725000013/t-20241231.htm
# Successfully downloaded: sec_filings_pdf\ATT INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1520262/000095017025019011/alks-20241231.htm
# Successfully downloaded: sec_filings_pdf\Alkermes plc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1976663/000147793225000919/nexscient_10q.htm
# Successfully downloaded: sec_filings_pdf\Nexscient Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/50471/000143774925003595/trak20241231c_10q.htm
# Successfully downloaded: sec_filings_pdf\ReposiTrak Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/882291/000168316825000960/aethlon_i10q-123124.htm
# Successfully downloaded: sec_filings_pdf\AETHLON MEDICAL INC_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1728951/000172895125000031/eprt-20241231.htm
# Successfully downloaded: sec_filings_pdf\ESSENTIAL PROPERTIES REALTY TRUST INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/915913/000091591325000026/alb-20241231.htm
# Successfully downloaded: sec_filings_pdf\ALBEMARLE CORP_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/709283/000070928325000003/qtm-20241231.htm
# Successfully downloaded: sec_filings_pdf\QUANTUM CORP DE_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1410384/000141038425000010/qtwo-20241231.htm
# Successfully downloaded: sec_filings_pdf\Q2 Holdings Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/885550/000088555025000012/cacc-20241231.htm
# Successfully downloaded: sec_filings_pdf\CREDIT ACCEPTANCE CORP_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1408075/000140807525000007/gpk-20241231.htm
# Successfully downloaded: sec_filings_pdf\GRAPHIC PACKAGING HOLDING CO_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/2011535/000114036125004062/ef20039380_10q.htm
# Successfully downloaded: sec_filings_pdf\Franklin Ethereum Trust_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1992870/000114036125004059/ef20039379_10q.htm
# Successfully downloaded: sec_filings_pdf\Franklin Templeton Digital Holdings Trust_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1058290/000105829025000017/ctsh-20241231.htm
# Successfully downloaded: sec_filings_pdf\COGNIZANT TECHNOLOGY SOLUTIONS CORP_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1286043/000128604325000014/krg-20241231.htm
# Successfully downloaded: sec_filings_pdf\Kite Realty Group LP_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1286043/000128604325000014/krg-20241231.htm
# Successfully downloaded: sec_filings_pdf\KITE REALTY GROUP TRUST_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1858258/000114036125004056/ef20039365_10q.htm
# Successfully downloaded: sec_filings_pdf\Franklin Templeton Holdings Trust_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/96793/000095017025018921/ssy-20241231.htm
# Successfully downloaded: sec_filings_pdf\SUNLINK HEALTH SYSTEMS INC_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/812074/000155837025000868/oi-20241231x10k.htm
# Successfully downloaded: sec_filings_pdf\O-I Glass Inc DE_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/353184/000035318425000009/airt-20241231.htm
# Successfully downloaded: sec_filings_pdf\AIR T INC_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1879103/000095017025018901/cfsb-20241231.htm
# Successfully downloaded: sec_filings_pdf\CFSB Bancorp Inc MA_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1629210/000095017025018900/pzg-20241231.htm
# Successfully downloaded: sec_filings_pdf\Paramount Gold Nevada Corp_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1997652/000162828025005147/trc-20241231.htm
# Successfully downloaded: sec_filings_pdf\Tamboran Resources Corp_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1509261/000155837025000867/rzlt-20241231x10q.htm
# Successfully downloaded: sec_filings_pdf\Rezolute Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1559998/000149315225006133/form10-q.htm
# Successfully downloaded: sec_filings_pdf\Gaucho Group Holdings Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1025378/000102537825000031/wpc-20241231.htm
# Successfully downloaded: sec_filings_pdf\W P Carey Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1404655/000095017025018873/hubs-20241231.htm
# Successfully downloaded: sec_filings_pdf\HUBSPOT INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/754811/000143774925003577/usglobal20241231_10q.htm
# Successfully downloaded: sec_filings_pdf\U S GLOBAL INVESTORS INC_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1110803/000111080325000019/ilmn-20241229.htm
# Successfully downloaded: sec_filings_pdf\ILLUMINA INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1428205/000142820525000027/arr-20241231.htm
# Successfully downloaded: sec_filings_pdf\Armour Residential REIT Inc_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1101302/000110130225000015/entg-20241231.htm
# Successfully downloaded: sec_filings_pdf\ENTEGRIS INC_10-K_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/1868640/000095017025018867/rdzn-20241231.htm
# Successfully downloaded: sec_filings_pdf\Roadzen Inc_10-Q_2025-02-12.pdf
# Downloading: https://www.sec.gov/Archives/edgar/data/913144/000091314425000009/rnr-20241231.htm
# Successfully downloaded: sec_filings_pdf\RENAISSANCERE HOLDINGS LTD_10-K_2025-02-12.pdf
#
# Download summary:
# Successfully downloaded: 198 / 200 filings
# Failed downloads: 2
# PDFs saved in: p:\Class\SPRING -2025\ADTA 5760 - Natural Language Processing with Artificial Neural Networks\Project\sec_filings_pdf
#
# Failed downloads details:
# URL: https://www.sec.gov/Archives/edgar/data/1725430/000149315225006477/form10-ka.htm
# Error: [Errno 2] No such file or directory: 'sec_filings_pdf\\INTELLIGENT BIO SOLUTIONS INC_10-K/A_2025-02-13.pdf'
#
# URL: https://www.sec.gov/Archives/edgar/data/1822250/000095017025020033/logc-20240930.htm
# Error: [Errno 2] No such file or directory: 'sec_filings_pdf\\ContextLogic Inc_10-Q/A_2025-02-13.pdf'
