# %%
#Build - Train - Test Recurrent Neural Networks
# Part IV: LSTM with Time-series Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read and prepare data
def load_temperature_data():
    url = 'https://data.giss.nasa.gov/gistemp/tabledata_v4/GLB.Ts+dSST.csv'
    df = pd.read_csv(url, skiprows=1)
    # Extract monthly temperature columns
    temp_columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    df_temps = df[temp_columns]
    # Convert to long format
    df_long = df_temps.melt(var_name='Month', value_name='Temperature')
    df_long['Year'] = np.repeat(df['Year'].values, 12)
    # Create datetime index
    df_long['Date'] = pd.to_datetime(df_long['Year'].astype(str) + '-' + df_long['Month'])
    df_long = df_long.sort_values('Date')
    # Remove missing values (marked as '***')
    df_long = df_long[df_long['Temperature'] != '***']
    df_long['Temperature'] = df_long['Temperature'].astype(float)
    return df_long.set_index('Date')[['Temperature']]

# %%
# Data preprocessing
def preprocess_data(df, test_split=0.2, sequence_length=24):
    # Scale the data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)
    
    # Create sequences
    X, y = [], []
    for i in range(len(scaled_data) - sequence_length):
        X.append(scaled_data[i:(i + sequence_length), 0])
        y.append(scaled_data[i + sequence_length, 0])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    
    # Split into train and test sets
    train_size = int(len(X) * (1-test_split))
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    
    return X_train, X_test, y_train, y_test, scaler

# %%
def build_model(sequence_length):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(sequence_length, 1)),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    
    model.compile(optimizer=Adam(learning_rate=0.001),
                 loss='mse',
                 metrics=['mae'])
    return model

# %%
def plot_results(history, y_test, y_pred, scaler):
    # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Plot predictions vs actual
    plt.subplot(1, 2, 2)
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred.reshape(-1, 1))
    
    plt.plot(y_test_inv, label='Actual')
    plt.plot(y_pred_inv, label='Predicted')
    plt.title('Temperature Predictions vs Actual')
    plt.xlabel('Time Steps')
    plt.ylabel('Temperature Anomaly (°C)')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Parameters
sequence_length = 24  # 2 years of monthly data
epochs = 100
batch_size = 32
validation_split = 0.1

# %%
# Load and preprocess data
df = load_temperature_data()
X_train, X_test, y_train, y_test, scaler = preprocess_data(df, sequence_length=sequence_length)
# Out:
# C:\Users\babebe\AppData\Local\Temp\ipykernel_48100\2285154615.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_long['Date'] = pd.to_datetime(df_long['Year'].astype(str) + '-' + df_long['Month'])

# %%
# Build and train model
model = build_model(sequence_length)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=validation_split,
    verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# C:\Users\babebe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0812 - mae: 0.2240 - val_loss: 0.0201 - val_mae: 0.1108
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199 - mae: 0.1063 - val_loss: 0.0163 - val_mae: 0.0944
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - mae: 0.0908 - val_loss: 0.0160 - val_mae: 0.0888
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143 - mae: 0.0872 - val_loss: 0.0145 - val_mae: 0.0893
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - mae: 0.0832 - val_loss: 0.0131 - val_mae: 0.0821
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135 - mae: 0.0852 - val_loss: 0.0126 - val_mae: 0.0807
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120 - mae: 0.0817 - val_loss: 0.0122 - val_mae: 0.0802
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115 - mae: 0.0811 - val_loss: 0.0133 - val_mae: 0.0859
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0111 - mae: 0.0766 - val_loss: 0.0115 - val_mae: 0.0772
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0128 - mae: 0.0804 - val_loss: 0.0117 - val_mae: 0.0779
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0121 - mae: 0.0819 - val_loss: 0.0144 - val_mae: 0.0906
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114 - mae: 0.0776 - val_loss: 0.0105 - val_mae: 0.0740
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0115 - mae: 0.0792 - val_loss: 0.0110 - val_mae: 0.0759
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114 - mae: 0.0794 - val_loss: 0.0101 - val_mae: 0.0724
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0113 - mae: 0.0779 - val_loss: 0.0109 - val_mae: 0.0781
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - mae: 0.0768 - val_loss: 0.0101 - val_mae: 0.0720
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - mae: 0.0743 - val_loss: 0.0119 - val_mae: 0.0812
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120 - mae: 0.0797 - val_loss: 0.0098 - val_mae: 0.0744
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0111 - mae: 0.0764 - val_loss: 0.0100 - val_mae: 0.0729
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0117 - mae: 0.0792 - val_loss: 0.0090 - val_mae: 0.0704
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0097 - mae: 0.0720 - val_loss: 0.0095 - val_mae: 0.0702
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0112 - mae: 0.0762 - val_loss: 0.0090 - val_mae: 0.0690
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0092 - mae: 0.0717 - val_loss: 0.0088 - val_mae: 0.0688
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0097 - mae: 0.0742 - val_loss: 0.0083 - val_mae: 0.0671
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093 - mae: 0.0708 - val_loss: 0.0091 - val_mae: 0.0691
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - mae: 0.0731 - val_loss: 0.0083 - val_mae: 0.0669
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0089 - mae: 0.0701 - val_loss: 0.0095 - val_mae: 0.0701
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - mae: 0.0740 - val_loss: 0.0078 - val_mae: 0.0650
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0103 - mae: 0.0752 - val_loss: 0.0090 - val_mae: 0.0696
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0096 - mae: 0.0723 - val_loss: 0.0082 - val_mae: 0.0672
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0090 - mae: 0.0702 - val_loss: 0.0081 - val_mae: 0.0667
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101 - mae: 0.0723 - val_loss: 0.0089 - val_mae: 0.0681
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082 - mae: 0.0688 - val_loss: 0.0087 - val_mae: 0.0685
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0092 - mae: 0.0701 - val_loss: 0.0080 - val_mae: 0.0667
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0085 - mae: 0.0673 - val_loss: 0.0090 - val_mae: 0.0680
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084 - mae: 0.0693 - val_loss: 0.0087 - val_mae: 0.0682
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089 - mae: 0.0706 - val_loss: 0.0079 - val_mae: 0.0656
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0095 - mae: 0.0697 - val_loss: 0.0078 - val_mae: 0.0662
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0093 - mae: 0.0707 - val_loss: 0.0076 - val_mae: 0.0654
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0099 - mae: 0.0734 - val_loss: 0.0090 - val_mae: 0.0691
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0088 - mae: 0.0677 - val_loss: 0.0089 - val_mae: 0.0691
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - mae: 0.0688 - val_loss: 0.0083 - val_mae: 0.0668
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mae: 0.0645 - val_loss: 0.0081 - val_mae: 0.0658
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086 - mae: 0.0710 - val_loss: 0.0076 - val_mae: 0.0642
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091 - mae: 0.0707 - val_loss: 0.0078 - val_mae: 0.0644
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0078 - mae: 0.0664 - val_loss: 0.0078 - val_mae: 0.0649
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0090 - mae: 0.0710 - val_loss: 0.0082 - val_mae: 0.0669
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - mae: 0.0644 - val_loss: 0.0087 - val_mae: 0.0673
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0077 - mae: 0.0675 - val_loss: 0.0085 - val_mae: 0.0666
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0077 - mae: 0.0664 - val_loss: 0.0079 - val_mae: 0.0661
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - mae: 0.0657 - val_loss: 0.0081 - val_mae: 0.0667
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - mae: 0.0651 - val_loss: 0.0091 - val_mae: 0.0698
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0087 - mae: 0.0687 - val_loss: 0.0082 - val_mae: 0.0660
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0076 - mae: 0.0648 - val_loss: 0.0083 - val_mae: 0.0663

# %%
# Make predictions
y_pred = model.predict(X_test)
# Plot results
plot_results(history, y_test, y_pred, scaler)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# Calculate and print metrics
mse = np.mean((y_test - y_pred.flatten())**2)
mae = np.mean(np.abs(y_test - y_pred.flatten()))
print(f'MSE: {mse:.4f}')
print(f'MAE: {mae:.4f}')
# Out:
# MSE: 0.0082
# MAE: 0.0670
